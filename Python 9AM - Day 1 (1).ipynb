# %%
print("Hi")
print('Hello')
# Out:
# Hi
# Hello

# %%
a = 123
print(a)
# Out:
# 123

# %%
Name = "Alex"
age = 25
Age = 30

print(Name)
print(Age)
# Out:
# Alex
# 30

# %%
a = 20
a = 30
a = 40

print(a)
# Out:
# 40

# %%
#This is my python class

print("Welcome")
# Out:
# Welcome

# %%
'''This is 
my python 
class'''

print("Welcome")
# Out:
# Welcome

# %%
a = """Hi  
How are you! 
Welcome"""

print(a)
# Out:
# Hi
# How are you!
# Welcome

# %%
N_ame = "hi"
print(N_ame)
# Out:
# hi

# %%
_Age = 23
print(_Age)
# Out:
# 23

# %%
Age23 = 23
print(Age23)
# Out:
# 23

# %%
Print = "Hi"
print(Print)
# Out:
# Hi

# %%
pnt = "hi"
print(pnt)
# Out:
# hi

# %%
'''
Arithmetic operator:
+	Addition
-	Subtraction
*	Multiplication
/	Division
//	Floor division
%	Modulus
**	Exponential
'''

# %%
a = 10
b = 20
print(a+b)

c = a+b
print(c)

print(c-a)
print(a*b)

a = c/b
print(a)

a = 10
print(a+b)
print(a//2)
print(a%2)
print(a%3)
print(a ** 2)
# Out:
# 30
# 30
# 20
# 200
# 1.5
# 30
# 5
# 0
# 1
# 100
